# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy 
from tools import *
# Out:
# C:\Users\peter\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
generator = data_generator('./anime-faces', 96, 96, batch_size=24, shuffle=True)
seq = get_imgaug()

# %%
batch, _ = generator.__getitem__(np.random.randint(len(generator)))
batch = np.round(batch*127.5 + 127.5).astype(np.uint8)
batch_aug = seq.augment_images(batch)
for n, (img, img_a) in enumerate(zip(batch, batch_aug)):
    x = np.concatenate([img, img_a], axis=1)
    plt.imshow(x)
    plt.axis('off')
    plt.show()
# Out:
# C:\Users\peter\Anaconda3\envs\tensorflow\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
